# %% [markdown]
# #Introduccion
# #### Script de python

# %%
5+8
# Out:
# 13

# %%
print("Hola Colab")
# Out:
# Hola Colab

# %% [markdown]
# ##Porcentajes
# juan tiene 3 manzanas y 1 pera. Pedro tiene 2 manzanas y 4 peras
# #### que porcentaje de frutas tienen en total

# %%
import pandas as pa
datos=pa.DataFrame({"Manzanas":[3,2],"Peras":[1,4]}, index=["Juan","Pedro"])
datos
# Out:
#        Manzanas  Peras
# Juan          3      1
# Pedro         2      4

# %%
datos.plot.bar()
# Out:
# <Axes: >

# %%
#@title Grafica de Pastel
datos["frutas en total"]=datos["Manzanas"]+datos["Peras"]
datos.plot.pie(y="frutas en total",autopct="%1.1f%%")
# Out:
# <Axes: ylabel='frutas en total'>
