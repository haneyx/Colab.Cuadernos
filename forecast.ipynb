# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# Generar datos de consumo de energía de ejemplo
np.random.seed(0)
t = np.arange(0, 100, 1)
consumo_energia = 10 * np.sin(0.2 * t) + np.random.normal(0, 2, size=len(t))

# Crear un DataFrame con los datos
data = pd.DataFrame({'tiempo': t, 'consumo_energia': consumo_energia})

# Visualizar los datos
plt.figure(figsize=(12, 6))
plt.plot(data['tiempo'], data['consumo_energia'])
plt.xlabel('Tiempo')
plt.ylabel('Consumo de Energía')
plt.title('Datos de Consumo de Energía')
plt.grid(True)
plt.show()

# Preparar los datos para el modelo de RNN
X = data['consumo_energia'].values
X_train = X[:-1]  # Usaremos todos los datos excepto el último para entrenar
y_train = X[1:]   # La siguiente muestra como objetivo

# Crear un modelo de RNN simple
model = Sequential()
model.add(SimpleRNN(32, activation='relu', input_shape=(1, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Entrenar el modelo
X_train = X_train.reshape(-1, 1, 1)
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Hacer un pronóstico a futuro
forecast_steps = 50  # Número de pasos a predecir en el futuro
X_test = X[-1].reshape(1, 1, 1)
forecast = []

for _ in range(forecast_steps):
    prediction = model.predict(X_test)
    forecast.append(prediction[0][0])
    X_test = np.roll(X_test, -1)  # Desplazar los datos de entrada
    X_test[-1][-1][0] = prediction[0][0]  # Agregar la predicción al final

# Crear un nuevo índice de tiempo para las predicciones
nuevo_tiempo = np.arange(100, 100 + forecast_steps, 1)

# Visualizar el pronóstico
plt.figure(figsize=(12, 6))
plt.plot(data['tiempo'], data['consumo_energia'], label='Datos reales')
plt.plot(nuevo_tiempo, forecast, label='Pronóstico', linestyle='dashed', color='orange')
plt.xlabel('Tiempo')
plt.ylabel('Consumo de Energía')
plt.title('Pronóstico de Consumo de Energía con una RNN')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50
# 13/13 [==============================] - 3s 14ms/step - loss: 72.7369
# Epoch 2/50
# 13/13 [==============================] - 0s 11ms/step - loss: 62.3801
# Epoch 3/50
# 13/13 [==============================] - 0s 8ms/step - loss: 53.8594
# Epoch 4/50
# 13/13 [==============================] - 0s 12ms/step - loss: 46.1533
# Epoch 5/50
# 13/13 [==============================] - 0s 7ms/step - loss: 39.7335
# Epoch 6/50
# 13/13 [==============================] - 0s 7ms/step - loss: 34.0671
# Epoch 7/50
# 13/13 [==============================] - 0s 7ms/step - loss: 29.1889
# Epoch 8/50
# 13/13 [==============================] - 0s 6ms/step - loss: 24.9654
# Epoch 9/50
# 13/13 [==============================] - 0s 11ms/step - loss: 21.2864
# Epoch 10/50
# 13/13 [==============================] - 0s 7ms/step - loss: 18.5646
# Epoch 11/50
# 13/13 [==============================] - 0s 12ms/step - loss: 15.9624
# Epoch 12/50
# 13/13 [==============================] - 0s 9ms/step - loss: 14.2162
# Epoch 13/50
# 13/13 [==============================] - 0s 10ms/step - loss: 12.7280
# Epoch 14/50
# 13/13 [==============================] - 0s 7ms/step - loss: 11.6977
# Epoch 15/50
# 13/13 [==============================] - 0s 6ms/step - loss: 10.8450
# Epoch 16/50
# 13/13 [==============================] - 0s 5ms/step - loss: 10.3285
# Epoch 17/50
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8384
# Epoch 18/50
# 13/13 [==============================] - 0s 6ms/step - loss: 9.5638
# Epoch 19/50
# 13/13 [==============================] - 0s 7ms/step - loss: 9.3513
# Epoch 20/50
# 13/13 [==============================] - 0s 7ms/step - loss: 9.2091
# Epoch 21/50
# 13/13 [==============================] - 0s 8ms/step - loss: 9.1259
# Epoch 22/50
# 13/13 [==============================] - 0s 8ms/step - loss: 9.0426
# Epoch 23/50
# 13/13 [==============================] - 0s 9ms/step - loss: 8.9855
# Epoch 24/50
# 13/13 [==============================] - 0s 4ms/step - loss: 8.9512
# Epoch 25/50
# 13/13 [==============================] - 0s 5ms/step - loss: 8.9377
# Epoch 26/50
# 13/13 [==============================] - 0s 3ms/step - loss: 8.9195
# Epoch 27/50
# 13/13 [==============================] - 0s 3ms/step - loss: 8.9093
# Epoch 28/50
# 13/13 [==============================] - 0s 4ms/step - loss: 8.9069
# Epoch 29/50
# 13/13 [==============================] - 0s 3ms/step - loss: 8.9026
# Epoch 30/50
# 13/13 [==============================] - 0s 6ms/step - loss: 8.8949
# Epoch 31/50
# 13/13 [==============================] - 0s 8ms/step - loss: 8.8938
# Epoch 32/50
# 13/13 [==============================] - 0s 4ms/step - loss: 8.8936
# Epoch 33/50
# 13/13 [==============================] - 0s 4ms/step - loss: 8.8877
# Epoch 34/50
# 13/13 [==============================] - 0s 7ms/step - loss: 8.8997
# Epoch 35/50
# 13/13 [==============================] - 0s 7ms/step - loss: 8.8906
# Epoch 36/50
# 13/13 [==============================] - 0s 4ms/step - loss: 8.8975
# Epoch 37/50
# 13/13 [==============================] - 0s 8ms/step - loss: 8.8962
# Epoch 38/50
# 13/13 [==============================] - 0s 7ms/step - loss: 8.8881
# Epoch 39/50
# 13/13 [==============================] - 0s 3ms/step - loss: 8.9079
# Epoch 40/50
# 13/13 [==============================] - 0s 5ms/step - loss: 8.8828
# Epoch 41/50
# 13/13 [==============================] - 0s 5ms/step - loss: 8.9318
# Epoch 42/50
# 13/13 [==============================] - 0s 6ms/step - loss: 8.9174
# Epoch 43/50
# 13/13 [==============================] - 0s 6ms/step - loss: 8.8860
# Epoch 44/50
# 13/13 [==============================] - 0s 4ms/step - loss: 8.8858
# Epoch 45/50
# 13/13 [==============================] - 0s 4ms/step - loss: 8.8903
# Epoch 46/50
# 13/13 [==============================] - 0s 4ms/step - loss: 8.8944
# Epoch 47/50
# 13/13 [==============================] - 0s 8ms/step - loss: 8.8823
# Epoch 48/50
# 13/13 [==============================] - 0s 5ms/step - loss: 8.8798
# Epoch 49/50
# 13/13 [==============================] - 0s 6ms/step - loss: 8.8949
# Epoch 50/50
# 13/13 [==============================] - 0s 4ms/step - loss: 8.8879
# 1/1 [==============================] - 0s 359ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 140ms/step
