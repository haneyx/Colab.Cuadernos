# %% [markdown]
# # <center> PYTHON - Estructura de datos </center>
#
# # I. Listas, tuplas y diccionarios

# %% [markdown]
# ## Ejercicio 1 - LISTAS
# Escribir un programa que almacene las asignaturas de un curso (por ejemplo Matemáticas, Física, Química, Historia y Lengua) en una lista y la muestre por pantalla.

# %%
# Crear una lista de asignaturas
asignaturas = ["Matemáticas", "Física", "Química", "Historia", "Lengua"]

# Mostrar la lista por pantalla
print("Asignaturas del curso:")
for asignatura in asignaturas:
    print(asignatura)
# Out:
# Asignaturas del curso:
# Matemáticas
# Física
# Química
# Historia
# Lengua

# %% [markdown]
# ## Ejercicio 2 - LISTAS
# Escribir un programa que almacene las asignaturas de un curso (por ejemplo Matemáticas, Física, Química, Historia y Lengua) en una lista y la muestre por pantalla el mensaje:
# * Yo estudio **ASIGNATURA**, donde **ASIGNATURA** es cada una de las asignaturas de la lista.

# %%
# Crear una lista de asignaturas
asignaturas = ["Matemáticas", "Física", "Química", "Historia", "Lengua"]

# Mostrar el mensaje personalizado por cada asignatura
for asignatura in asignaturas:
    print(f"Yo estudio {asignatura}")
# Out:
# Yo estudio Matemáticas
# Yo estudio Física
# Yo estudio Química
# Yo estudio Historia
# Yo estudio Lengua

# %% [markdown]
# ## Ejercicio 3 - LISTAS
# Escribir un programa que almacene las asignaturas de un curso (por ejemplo Matemáticas, Física, Química, Historia y Lengua) en una lista, pregunte al usuario la nota que ha sacado en cada asignatura, y después las muestre por pantalla con el mensaje:
# * En **ASIGNATURA** has sacado **NOTA** donde **ASIGNATURA** es cada una des las asignaturas de la lista y **NOTA** cada una de las correspondientes notas introducidas por el usuario.

# %%
# Crear una lista de asignaturas
asignaturas = ["Matemáticas", "Física", "Química", "Historia", "Lengua"]

# Crear un diccionario para almacenar las notas
notas = {}

# Solicitar al usuario la nota para cada asignatura
for asignatura in asignaturas:
    nota = float(input(f"Ingrese la nota de {asignatura}: "))
    notas[asignatura] = nota

# Mostrar las notas por pantalla
for asignatura, nota in notas.items():
    print(f"En {asignatura} has sacado {nota}")
# Out:
# Ingrese la nota de Matemáticas: 19
# Ingrese la nota de Física: 20
# Ingrese la nota de Química: 15
# Ingrese la nota de Historia: 12
# Ingrese la nota de Lengua: 14
# En Matemáticas has sacado 19.0
# En Física has sacado 20.0
# En Química has sacado 15.0
# En Historia has sacado 12.0
# En Lengua has sacado 14.0

# %% [markdown]
# # Ejercicio 4 - DICCIONARIO
# Escribir un programa que guarde en una variable el diccionario {'Euro':'€', 'Dollar':'$', 'Yen':'¥'}, pregunte al usuario por una divisa y muestre su símbolo o un mensaje de aviso si la divisa no está en el diccionario.

# %%
# Definir el diccionario de divisas
diccionario_divisas = {'Euro': '€', 'Dollar': '$', 'Yen': '¥'}

# Solicitar al usuario ingresar una divisa
divisa = input("Ingrese una divisa: ")

# Obtener el símbolo de la divisa del diccionario
simbolo = diccionario_divisas.get(divisa)

# Mostrar el resultado
if simbolo is not None:
    print(f"El símbolo de {divisa} es {simbolo}")
else:
    print(f"La divisa {divisa} no está en el diccionario.")
# Out:
# Ingrese una divisa: S/.
# La divisa S/. no está en el diccionario.

# %% [markdown]
# # Ejercicio 5 - DICCIONARIO
# Escribir un programa que pregunte al usuario su nombre, edad, dirección y teléfono y lo guarde en un diccionario. Después debe mostrar por pantalla el mensaje <nombre> tiene <edad> años, vive en <dirección> y su número de teléfono es <teléfono>.

# %%
# Solicitar al usuario información personal
nombre = input("Ingrese su nombre: ")
edad = input("Ingrese su edad: ")
direccion = input("Ingrese su dirección: ")
telefono = input("Ingrese su número de teléfono: ")

# Crear un diccionario con la información del usuario
informacion_usuario = {
    'Nombre': nombre,
    'Edad': edad,
    'Dirección': direccion,
    'Teléfono': telefono
}

# Mostrar la información por pantalla
mensaje = f"{informacion_usuario['Nombre']} tiene {informacion_usuario['Edad']} años, vive en {informacion_usuario['Dirección']} y su número de teléfono es {informacion_usuario['Teléfono']}."
print(mensaje)
# Out:
# Ingrese su nombre: Docente
# Ingrese su edad: 20
# Ingrese su dirección: Av. SiempreViva 145
# Ingrese su número de teléfono: 951123345
# Docente tiene 20 años, vive en Av. SiempreViva 145 y su número de teléfono es 951123345.

# %% [markdown]
# ## Ejercicio 6 - DICCIONARIO
#
# Escribir un programa que guarde en un diccionario los precios de las frutas de la tabla, pregunte al usuario por una fruta, un número de kilos y muestre por pantalla el precio de ese número de kilos de fruta. Si la fruta no está en el diccionario debe mostrar un mensaje informando de ello.
#
# | Fruta | Precio|
# |:-|:-:|
# |Plátano | 1.35 |
# |Manzana | 0.80|
# |Pera| 0.85|
# |Naranja | 0.70|

# %%
# Definir el diccionario de precios de frutas
precios_frutas = {
    'Plátano': 1.35,
    'Manzana': 0.80,
    'Pera': 0.85,
    'Naranja': 0.70
}

# Solicitar al usuario la fruta y el número de kilos
fruta = input("Ingrese el nombre de la fruta: ")

# Verificar si la fruta está en el diccionario
if fruta in precios_frutas:
    try:
        kilos = float(input("Ingrese el número de kilos: "))
        # Calcular el precio y mostrar por pantalla
        precio_total = precios_frutas[fruta] * kilos
        print(f"El precio de {kilos} kilos de {fruta} es: {precio_total} euros.")
    except ValueError:
        print("Por favor, ingrese un número válido de kilos.")
else:
    print(f"{fruta} no está en el diccionario de precios.")
p
# Out:
# Ingrese el nombre de la fruta: Manzana
# Ingrese el número de kilos: 2
# El precio de 2.0 kilos de Manzana es: 1.6 euros.
